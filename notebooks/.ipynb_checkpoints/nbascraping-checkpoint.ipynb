# %%
import os
from bs4 import BeautifulSoup
from playwright.async_api import async_playwright, TimeoutError as PlaywrightTimeout
import time

# %%
SEASONS = list(range(2020, 2026))

# %%
DATA_DIR = "NBAdata"
STANDINGS_DIR = os.path.join(DATA_DIR, "standings")
SCORES_DIR = os.path.join(DATA_DIR, "scores")

# %%
async def get_html(url, selector, sleep=5, retries=3):
    html = None
    for i in range(1, retries+1): #Try it about 3 times
        time.sleep(sleep * i) #Space it out so don't get banned
        
        try: 
            async with async_playwright() as p:
                browser = await p.firefox.launch() #launch chrome
                page = await browser.new_page() #create tab
                await page.goto(url) #go to the url
                print(await page.title())
                html = await page.inner_html(selector) #selector is 
                #like the group box/a header
        except PlaywrightTimeout:
            print(f"Timeout error on {url}")
            continue
        else:
            break
        
    return html

# %%
async def scrape_season(season):
    url = f"https://www.basketball-reference.com/leagues/NBA_{season}_games.html"
    html = await get_html(url, "#content .filter")
    
    soup = BeautifulSoup(html)
    links = soup.find_all("a") #find all a-tags/anchors
    #href = [l["href"] for l in links]
    standings_pages = [f"https://basketball-reference.com{l['href']}" for l in links]

    for url in standings_pages:
        save_path = os.path.join(STANDINGS_DIR, url.split("/")[-1])
        if os.path.exists(save_path):
            continue
            
        html = await get_html(url, "#all_schedule")
        with open(save_path, "w+") as f:
            f.write(html)

# %%
for season in SEASONS:
    await scrape_season(season)
# Out:
# 2019-20 NBA Schedule | Basketball-Reference.com
# 2019-20 NBA Schedule | Basketball-Reference.com
# 2019-20 NBA Schedule | Basketball-Reference.com
# 2019-20 NBA Schedule | Basketball-Reference.com
# 2019-20 NBA Schedule | Basketball-Reference.com
# 2019-20 NBA Schedule | Basketball-Reference.com
# 2019-20 NBA Schedule | Basketball-Reference.com
# 2019-20 NBA Schedule | Basketball-Reference.com
# 2019-20 NBA Schedule | Basketball-Reference.com
# 2019-20 NBA Schedule | Basketball-Reference.com
# 2019-20 NBA Schedule | Basketball-Reference.com
# 2020-21 NBA Schedule | Basketball-Reference.com
# 2020-21 NBA Schedule | Basketball-Reference.com
# 2020-21 NBA Schedule | Basketball-Reference.com
# 2020-21 NBA Schedule | Basketball-Reference.com
# 2020-21 NBA Schedule | Basketball-Reference.com
# 2020-21 NBA Schedule | Basketball-Reference.com
# 2020-21 NBA Schedule | Basketball-Reference.com
# 2020-21 NBA Schedule | Basketball-Reference.com
# 2021-22 NBA Schedule | Basketball-Reference.com
# ...

# %%
standings_files = os.listdir(STANDINGS_DIR)

# %%
async def scrape_game(standings_file):
    
    with open(standings_file, 'r') as f:
        html = f.read()

    soup = BeautifulSoup(html)
    links = soup.find_all("a")
    hrefs = [l.get("href") for l in links]
    box_scores = [l for l in hrefs if l and "boxscore" in l and ".html" in l]
    box_scores = [f"https://www.basketball-reference.com{l}" for l in box_scores]

    for url in box_scores:
        save_path = os.path.join(SCORES_DIR, url.split("/")[-1])
        if os.path.exists(save_path):
            continue

        html = await get_html(url, "#content")
        if not html:
            continue
        with open(save_path, "w+") as f:
                f.write(html)

# %%
standings_files = [s for s in standings_files if ".html" in s]

# %%
for f in standings_files:
    filepath = os.path.join(STANDINGS_DIR, f)

    await scrape_game(filepath)
# Out:
# Cavaliers vs Knicks, February 28, 2019 | Basketball-Reference.com
# Cavaliers vs Hornets, November 1, 2021 | Basketball-Reference.com
# Spurs vs Pacers, November 1, 2021 | Basketball-Reference.com
# Trail Blazers vs 76ers, November 1, 2021 | Basketball-Reference.com
# Wizards vs Hawks, November 1, 2021 | Basketball-Reference.com
# Bulls vs Celtics, November 1, 2021 | Basketball-Reference.com
# Raptors vs Knicks, November 1, 2021 | Basketball-Reference.com
# Nuggets vs Grizzlies, November 1, 2021 | Basketball-Reference.com
# Magic vs Timberwolves, November 1, 2021 | Basketball-Reference.com
# Thunder vs Clippers, November 1, 2021 | Basketball-Reference.com
# Bucks vs Pistons, November 2, 2021 | Basketball-Reference.com
# Heat vs Mavericks, November 2, 2021 | Basketball-Reference.com
# Kings vs Jazz, November 2, 2021 | Basketball-Reference.com
# Pelicans vs Suns, November 2, 2021 | Basketball-Reference.com
# Rockets vs Lakers, November 2, 2021 | Basketball-Reference.com
# ...
